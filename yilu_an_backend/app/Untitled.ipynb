# %%
from langchain_openai import ChatOpenAI

# %%
# 初始化模型
llm = ChatOpenAI(
    model="deepseek-ai/DeepSeek-V3.2",  # 指定 Omni 系列模型名称
    api_key="ms-1e925ea1-6998-49c2-83f7-1b0498221e24",
    base_url="https://api-inference.modelscope.cn/v1",
    temperature=0,             # 设置为0以获得更稳定的工具调用结果
)

# %%
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000197DFC69A90>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000197E01C6190>, root_client=<openai.OpenAI object at 0x00000197DFC65D90>, root_async_client=<openai.AsyncOpenAI object at 0x00000197E01C5E90>, model_name='qwen3-omni-flash', temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='qwen3-omni-flash')

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
ChatPromptTemplate
# Out:
# langchain_core.prompts.chat.ChatPromptTemplate

# %%
template_string = """请将文本转述成更{style}的风格。\

请将输出为键如下的JSON格式：
original_text
style
polish_text

original_text指原始输入，style是指定风格，polish_text是转述后的文本。\

text:```{text}```"""

# %%
prompt_template = ChatPromptTemplate.from_template(template_string)
prompt_template
# Out:
# ChatPromptTemplate(input_variables=['style', 'text'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['style', 'text'], input_types={}, partial_variables={}, template='请将文本转述成更{style}的风格。text:```{text}```'), additional_kwargs={})])

# %%
style = "温和"

# %%
words = "你怎么这么笨什么事情都做不好！！！"

# %%
msg = prompt_template.format_messages(style=style,text=words)

# %%
msg
# Out:
# [HumanMessage(content='请将文本转述成更温和的风格。text:```你怎么这么笨什么事情都做不好！！！```', additional_kwargs={}, response_metadata={})]

# %%
res = llm.invoke(msg)
res
# Out:
# AIMessage(content='看来这件事确实让你有些沮丧呢。我们可以一起看看问题出在哪里，一起想办法解决。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 26, 'total_tokens': 45, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'deepseek-ai/DeepSeek-V3.2', 'system_fingerprint': '', 'id': 'chatcmpl-9d4cd707-ced2-9ac3-b900-a3216610d3e4', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d782a-20ba-7160-bc2e-3c33323dc767-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 19, 'total_tokens': 45, 'input_token_details': {}, 'output_token_details': {}})

# %%
res.content
# Out:
# '看来这件事确实让你有些沮丧呢。我们可以一起看看问题出在哪里，一起想办法解决。'
